# %%
# !pip install neptune
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.9/487.9 kB 38.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 144.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.1 MB/s eta 0:00:00
# ...
#   Created wheel for bravado-core: filename=bravado_core-6.1.1-py2.py3-none-any.whl size=67675 sha256=d127791287abb5e493b495f8fcb42ef62401b0a0ecaa67a623b94403a01f4030
#   Stored in directory: /root/.cache/pip/wheels/b8/56/c6/3695a1daf18ee45607f1d352fca288d173bc3b1722228c6fb1
# Successfully built bravado-core
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %load_ext autoreload
# %autoreload 2
from dataloader import create_dataloader
from model import LLaMA
from train_loop import train_loop
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/996 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("ashaba1in/small_openwebtext")
# Out:
# README.md:   0%|          | 0.00/286 [00:00<?, ?B/s]
# data/train-00000-of-00010.parquet:   0%|          | 0.00/303M [00:00<?, ?B/s]
# data/train-00001-of-00010.parquet:   0%|          | 0.00/305M [00:00<?, ?B/s]
# data/train-00002-of-00010.parquet:   0%|          | 0.00/304M [00:00<?, ?B/s]
# data/train-00003-of-00010.parquet:   0%|          | 0.00/304M [00:00<?, ?B/s]
# data/train-00004-of-00010.parquet:   0%|          | 0.00/301M [00:00<?, ?B/s]
# data/train-00005-of-00010.parquet:   0%|          | 0.00/301M [00:00<?, ?B/s]
# data/train-00006-of-00010.parquet:   0%|          | 0.00/303M [00:00<?, ?B/s]
# data/train-00007-of-00010.parquet:   0%|          | 0.00/300M [00:00<?, ?B/s]
# data/train-00008-of-00010.parquet:   0%|          | 0.00/302M [00:00<?, ?B/s]
# data/train-00009-of-00010.parquet:   0%|          | 0.00/302M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1000000 [00:00<?, ? examples/s]

# %%
from dataloader import create_dataloader
loader = create_dataloader(dataset)
model = LLaMA()
model = model.to("cuda")

# %%
import torch
chkp = torch.load('/content/drive/MyDrive/Копия model_step7_tokens175036226.pt', map_location='cuda')

# %%
trainer = train_loop(model)
trainer.train(loader, chkp)
# Out:
# /content/train_loop.py:85: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler()
#  70%|#######   | 175036226/250000000.0 [00:00<?, ?it/s]
# /usr/lib/python3.12/contextlib.py:105: FutureWarning: `torch.backends.cuda.sdp_kernel()` is deprecated. In the future, this context manager will be removed. Please see `torch.nn.attention.sdpa_kernel()` for the new context manager, with updated signature.
#   self.gen = func(*args, **kwds)
# Checkpoint saved: /content/drive/MyDrive/checkpoints/model_step8_tokens200173336.pt
# Checkpoint saved: /content/drive/MyDrive/checkpoints/model_step9_tokens225062796.pt
# Checkpoint saved: /content/drive/MyDrive/checkpoints/model_step10_tokens250223274.pt
